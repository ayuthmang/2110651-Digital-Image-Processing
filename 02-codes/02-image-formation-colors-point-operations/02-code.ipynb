# %% [markdown]
# # Week #2 Image Formation, Colors, Point Operations

# %%
# !wget "https://drive.google.com/uc?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe" -O kitty.jpg
# !wget "https://drive.google.com/uc?id=18oft21cCMRsIYwJ0-abLc3mrWAonHGSW" -O rgb.png
# Out:
# --2025-09-18 18:29:52--  https://drive.google.com/uc?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:817::200e, 172.217.25.46
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:817::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe [following]
# --2025-09-18 18:29:53--  https://drive.usercontent.google.com/download?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 2404:6800:4001:805::2001, 172.217.25.65
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|2404:6800:4001:805::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79570 (78K) [image/jpeg]
# Saving to: ‘kitty.jpg’
#
# kitty.jpg           100%[===================>]  77.71K  --.-KB/s    in 0.1s
#
# 2025-09-18 18:29:55 (524 KB/s) - ‘kitty.jpg’ saved [79570/79570]
#
# --2025-09-18 18:29:55--  https://drive.google.com/uc?id=18oft21cCMRsIYwJ0-abLc3mrWAonHGSW
# Resolving drive.google.com (drive.google.com)... 2404:6800:4001:817::200e, 172.217.25.46
# Connecting to drive.google.com (drive.google.com)|2404:6800:4001:817::200e|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=18oft21cCMRsIYwJ0-abLc3mrWAonHGSW [following]
# --2025-09-18 18:29:56--  https://drive.usercontent.google.com/download?id=18oft21cCMRsIYwJ0-abLc3mrWAonHGSW
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 2404:6800:4001:805::2001, 172.217.25.65
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|2404:6800:4001:805::2001|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 119240 (116K) [image/png]
# Saving to: ‘rgb.png’
#
# rgb.png             100%[===================>] 116.45K   587KB/s    in 0.2s
#
# 2025-09-18 18:29:58 (587 KB/s) - ‘rgb.png’ saved [119240/119240]

# %% [markdown]
# ## Exercise #1 Quantization
# * 2 bits

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import io, color
import numpy as np

img = io.imread("kitty.jpg")
gray = color.rgb2gray(img)  # -> 8-bit 0-255
# TO DO: Quantize the grayscale image to have 2 bits or 4 colors

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# * Quantize an image to be represented by 1 bit

# %% [markdown]
# ## Exercise #2 Shrink and Zoom
# * Shrink an image to 64 x 64
# * Zoom in an image to 1000 x 1000

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import io, color
import numpy as np

img = io.imread("kitty.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import io, color
import numpy as np

# Shrink
SIZE = 64

img = cv2.imread("kitty.jpg")
img_resize_nn = cv2.resize(img, (SIZE, SIZE), interpolation=cv2.INTER_NEAREST)  # nearest
img_resize_bc = cv2.resize(img, (SIZE, SIZE), interpolation=cv2.INTER_CUBIC)  # bicubic

# TO DO : Try with AREA & LINEAR INTERPOLATION TECHNIQUES

# Write your code to visualize the results
plt.imshow(img_resize_nn[:, :, ::-1])
plt.axis('off')
plt.show()

plt.imshow(img_resize_bc[:, :, ::-1])
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import io, color
import numpy as np

# Zoom in
SIZE = 1000

# %% [markdown]
# ## Exercise #3 Arithmetic Operations
# * Gain
# * Bias

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

GAIN = 2

img = cv2.imread("kitty.jpg")

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img_div = cv2.divide(img_gray,GAIN)
img_mul = cv2.multiply(img_gray,GAIN)

# Write your code to visualize the results
plt.imshow(img_gray,cmap='gray')
plt.axis('off')
plt.show()

plt.imshow(img_mul,cmap='gray')
plt.axis('off')
plt.show()

# %%
print(img_mul.min(),img_mul.max())
# Out:
# 0 255

# %%
img_mul = img_gray * 2
print(img_mul.min(),img_mul.max())
plt.imshow(img_mul,cmap='gray')
plt.show()
# Out:
# 0 254

# %%
# TO DO : use the bias of 50 and -50
import cv2
import numpy as np
import matplotlib.pyplot as plt

BIAS = 50

img = cv2.imread("kitty.jpg")

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img_add = cv2.add(img_gray,BIAS)
img_sub = cv2.subtract(img_gray,BIAS)


# Write your code to visualize the results
plt.imshow(img_gray,cmap='gray')
plt.axis('off')
plt.show()

plt.imshow(img_add,cmap='gray',vmin=0,vmax=255)
plt.axis('off')
plt.show()

# %%
# Playing with RGB image

# working with RGB
GAIN = (2,2,2,1)
img = cv2.imread("kitty.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_div = cv2.divide(img_rgb,GAIN)
img_mul = cv2.multiply(img_rgb,GAIN)

# Write your code to visualize the results

# %% [markdown]
# ## Exercise #4 Color Models
#
# Select one of the following color models, visualize each component in the model and analyze the results
# -------
# * HSV
# * YCbCr
# * CIELAB

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("rgb.png")
plt.imshow(img[:,:,::-1])
plt.show()

img_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV) # H S V
print(img_hsv.shape)

plt.imshow(img_hsv[:,:,0],cmap='gray')
plt.title('H')
plt.show()
# Out:
# (1132, 1206, 3)
